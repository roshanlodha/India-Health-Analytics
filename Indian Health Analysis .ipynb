# %% [markdown]
# Section 0: Title and Awknowledgements

# %%
#imports 
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Section 1: Introduction

# %%
#load dataset
statewise = pd.read_csv('india_health_state.csv')
statewise.head(5)

# %%
statewise.columns.values

# %% [markdown]
# Section 2: Data Cleaning

# %% [markdown]
# Section 3: Exploratory Data Analysis

# %% [markdown]
# Section 4: Modeling

# %% [markdown]
# Section 5: Conclusions
